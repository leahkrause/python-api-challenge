# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os

# Import the OpenWeatherMap API key
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("open_weather_api_key")

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + '&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
                
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["main"]["temp_max"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gaur
# Processing Record 2 of Set 1 | kidodi
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | esperance
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 1 | ancud
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | fairbanks
# Processing Record 15 of Set 1 | luderitz
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | qaqortoq
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | camacha
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | tuatapere
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | kibala
# Processing Record 30 of Set 1 | puerto morazan
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | totoral
# Processing Record 33 of Set 1 | atasu
# Processing Record 34 of Set 1 | vanimo
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | sao joao da barra
# Processing Record 37 of Set 1 | lagoa
# Processing Record 38 of Set 1 | brae
# Processing Record 39 of Set 1 | atar
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | edd
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | alofi
# Processing Record 44 of Set 1 | namwala
# Processing Record 45 of Set 1 | kruisfontein
# Processing Record 46 of Set 1 | evensk
# Processing Record 47 of Set 1 | loviisa
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 0 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | bull savanna
# Processing Record 2 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 2 | chulman
# Processing Record 4 of Set 2 | kirakira
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | palmer
# Processing Record 7 of Set 2 | kaspiyskiy
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | piacabucu
# Processing Record 10 of Set 2 | khatanga
# Processing Record 11 of Set 2 | ippy
# Processing Record 12 of Set 2 | rurrenabaque
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | inongo
# Processing Record 17 of Set 2 | talnakh
# Processing Record 18 of Set 2 | bengkulu
# Processing Record 19 of Set 2 | sipe sipe
# Processing Record 20 of Set 2 | guadalupe y calvo
# Processing Record 21 of Set 2 | taksimo
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | labuhan
# Processing Record 25 of Set 2 | san vicente
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | coquimbo
# Processing Record 29 of Set 2 | salihli
# Processing Record 30 of Set 2 | mulchen
# Processing Record 31 of Set 2 | flinders
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 2 | stepnyak
# Processing Record 35 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 36 of Set 2 | la rioja
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | pingliang
# Processing Record 39 of Set 2 | fare
# Processing Record 40 of Set 2 | linshu
# City not found. Skipping...
# Processing Record 41 of Set 2 | oneida
# Processing Record 42 of Set 2 | hasaki
# Processing Record 43 of Set 2 | shurugwi
# Processing Record 44 of Set 2 | saint-leu
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | pelym
# Processing Record 49 of Set 2 | west lorne
# Processing Record 0 of Set 3 | muros
# Processing Record 1 of Set 3 | prieska
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | albany
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | norman wells
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | sorland
# Processing Record 10 of Set 3 | honiara
# Processing Record 11 of Set 3 | veraval
# Processing Record 12 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | dien bien
# City not found. Skipping...
# Processing Record 15 of Set 3 | martin
# Processing Record 16 of Set 3 | ust-kut
# Processing Record 17 of Set 3 | florina
# Processing Record 18 of Set 3 | maragogi
# Processing Record 19 of Set 3 | pacific grove
# Processing Record 20 of Set 3 | vardo
# Processing Record 21 of Set 3 | lagos
# Processing Record 22 of Set 3 | bogoslovka
# Processing Record 23 of Set 3 | hofn
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | xining
# Processing Record 26 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 3 | half moon bay
# Processing Record 29 of Set 3 | abnub
# Processing Record 30 of Set 3 | chuy
# Processing Record 31 of Set 3 | lorengau
# Processing Record 32 of Set 3 | victoria
# Processing Record 33 of Set 3 | magadan
# Processing Record 34 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 3 | sao filipe
# Processing Record 36 of Set 3 | bandarbeyla
# Processing Record 37 of Set 3 | guacimo
# Processing Record 38 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 3 | constitucion
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 42 of Set 3 | samarai
# Processing Record 43 of Set 3 | joshimath
# Processing Record 44 of Set 3 | pitimbu
# Processing Record 45 of Set 3 | kenai
# Processing Record 46 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 3 | saint-augustin
# Processing Record 48 of Set 3 | atambua
# Processing Record 49 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 0 of Set 4 | pizarro
# Processing Record 1 of Set 4 | hilo
# Processing Record 2 of Set 4 | maceio
# Processing Record 3 of Set 4 | lompoc
# Processing Record 4 of Set 4 | general roca
# Processing Record 5 of Set 4 | dukat
# Processing Record 6 of Set 4 | adwa
# Processing Record 7 of Set 4 | homer
# Processing Record 8 of Set 4 | port hueneme
# Processing Record 9 of Set 4 | celestun
# Processing Record 10 of Set 4 | berlevag
# Processing Record 11 of Set 4 | freeport
# Processing Record 12 of Set 4 | saint-pierre
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | tabuk
# Processing Record 16 of Set 4 | carutapera
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | jagannathpur
# Processing Record 19 of Set 4 | menongue
# Processing Record 20 of Set 4 | jambi
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | tiksi
# Processing Record 23 of Set 4 | hobart
# Processing Record 24 of Set 4 | tambul
# City not found. Skipping...
# Processing Record 25 of Set 4 | cabedelo
# Processing Record 26 of Set 4 | atlantic city
# Processing Record 27 of Set 4 | hirado
# Processing Record 28 of Set 4 | malinovskiy
# Processing Record 29 of Set 4 | egvekinot
# Processing Record 30 of Set 4 | lazaro cardenas
# Processing Record 31 of Set 4 | taraz
# Processing Record 32 of Set 4 | nikolskoye
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | yulara
# Processing Record 35 of Set 4 | vao
# Processing Record 36 of Set 4 | terrak
# Processing Record 37 of Set 4 | north bend
# Processing Record 38 of Set 4 | te anau
# Processing Record 39 of Set 4 | araouane
# Processing Record 40 of Set 4 | sazonovo
# Processing Record 41 of Set 4 | alta
# Processing Record 42 of Set 4 | mattru
# Processing Record 43 of Set 4 | nouadhibou
# Processing Record 44 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 4 | canon city
# Processing Record 46 of Set 4 | gogrial
# Processing Record 47 of Set 4 | faya
# Processing Record 48 of Set 4 | thiadiaye
# Processing Record 49 of Set 4 | kavaratti
# Processing Record 0 of Set 5 | juba
# Processing Record 1 of Set 5 | meulaboh
# Processing Record 2 of Set 5 | itaituba
# Processing Record 3 of Set 5 | broome
# Processing Record 4 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 5 | beyneu
# Processing Record 6 of Set 5 | sosnovo-ozerskoye
# Processing Record 7 of Set 5 | los llanos de aridane
# Processing Record 8 of Set 5 | casablanca
# Processing Record 9 of Set 5 | hovd
# Processing Record 10 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 5 | douglas
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | faanui
# Processing Record 14 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 15 of Set 5 | hualmay
# Processing Record 16 of Set 5 | paamiut
# Processing Record 17 of Set 5 | cherskiy
# Processing Record 18 of Set 5 | treinta y tres
# Processing Record 19 of Set 5 | opuwo
# Processing Record 20 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 5 | sitka
# Processing Record 22 of Set 5 | robertsport
# Processing Record 23 of Set 5 | byron bay
# Processing Record 24 of Set 5 | lukovetskiy
# Processing Record 25 of Set 5 | riwaka
# Processing Record 26 of Set 5 | julio de castilhos
# Processing Record 27 of Set 5 | beringovskiy
# Processing Record 28 of Set 5 | el estor
# Processing Record 29 of Set 5 | jaru
# Processing Record 30 of Set 5 | russell
# Processing Record 31 of Set 5 | grand gaube
# Processing Record 32 of Set 5 | merauke
# Processing Record 33 of Set 5 | najran
# Processing Record 34 of Set 5 | georgetown
# Processing Record 35 of Set 5 | kuah
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | karpathos
# Processing Record 38 of Set 5 | ustka
# Processing Record 39 of Set 5 | maniitsoq
# Processing Record 40 of Set 5 | dunedin
# Processing Record 41 of Set 5 | cam ranh
# Processing Record 42 of Set 5 | malindi
# Processing Record 43 of Set 5 | mahon
# Processing Record 44 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 5 | souillac
# Processing Record 46 of Set 5 | esso
# Processing Record 47 of Set 5 | paciran
# Processing Record 48 of Set 5 | glyadyanskoye
# Processing Record 49 of Set 5 | ribeira grande
# Processing Record 0 of Set 6 | coatepeque
# Processing Record 1 of Set 6 | port lincoln
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | novolugovoye
# Processing Record 4 of Set 6 | raga
# Processing Record 5 of Set 6 | ust-tsilma
# Processing Record 6 of Set 6 | codrington
# Processing Record 7 of Set 6 | auki
# Processing Record 8 of Set 6 | innisfail
# Processing Record 9 of Set 6 | san patricio
# Processing Record 10 of Set 6 | mutoko
# Processing Record 11 of Set 6 | termiz
# Processing Record 12 of Set 6 | kismayo
# Processing Record 13 of Set 6 | pullman
# Processing Record 14 of Set 6 | dogondoutchi
# Processing Record 15 of Set 6 | alta floresta
# Processing Record 16 of Set 6 | hays
# Processing Record 17 of Set 6 | husavik
# Processing Record 18 of Set 6 | mawlaik
# Processing Record 19 of Set 6 | pevek
# Processing Record 20 of Set 6 | ravar
# Processing Record 21 of Set 6 | aswan
# Processing Record 22 of Set 6 | bend
# Processing Record 23 of Set 6 | limbang
# Processing Record 24 of Set 6 | vila franca do campo
# Processing Record 25 of Set 6 | whitehorse
# Processing Record 26 of Set 6 | coria
# Processing Record 27 of Set 6 | bahia blanca
# Processing Record 28 of Set 6 | san quintin
# Processing Record 29 of Set 6 | gamba
# Processing Record 30 of Set 6 | port blair
# Processing Record 31 of Set 6 | cockburn town
# Processing Record 32 of Set 6 | amilly
# Processing Record 33 of Set 6 | dawei
# Processing Record 34 of Set 6 | knysna
# Processing Record 35 of Set 6 | severo-kurilsk
# Processing Record 36 of Set 6 | othonoi
# City not found. Skipping...
# Processing Record 37 of Set 6 | sinnamary
# Processing Record 38 of Set 6 | dikson
# Processing Record 39 of Set 6 | port macquarie
# Processing Record 40 of Set 6 | uruzgan
# Processing Record 41 of Set 6 | mbini
# Processing Record 42 of Set 6 | valle del guamuez
# Processing Record 43 of Set 6 | comodoro rivadavia
# Processing Record 44 of Set 6 | kahului
# Processing Record 45 of Set 6 | cadereyta
# Processing Record 46 of Set 6 | karratha
# Processing Record 47 of Set 6 | clyde river
# Processing Record 48 of Set 6 | shakhrinau
# City not found. Skipping...
# Processing Record 49 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 0 of Set 7 | torbay
# Processing Record 1 of Set 7 | gouyave
# Processing Record 2 of Set 7 | leshukonskoye
# Processing Record 3 of Set 7 | leningradskiy
# Processing Record 4 of Set 7 | bayir
# Processing Record 5 of Set 7 | maningrida
# Processing Record 6 of Set 7 | georgiyevka
# Processing Record 7 of Set 7 | katsuura
# Processing Record 8 of Set 7 | mabaruma
# Processing Record 9 of Set 7 | tyrma
# Processing Record 10 of Set 7 | dzialdowo
# Processing Record 11 of Set 7 | emba
# Processing Record 12 of Set 7 | bacolod
# Processing Record 13 of Set 7 | fagernes
# Processing Record 14 of Set 7 | sibolga
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | zyryanovsk
# Processing Record 17 of Set 7 | shingu
# Processing Record 18 of Set 7 | balkanabat
# Processing Record 19 of Set 7 | touros
# Processing Record 20 of Set 7 | litoral del san juan
# City not found. Skipping...
# Processing Record 21 of Set 7 | arlit
# Processing Record 22 of Set 7 | nassau
# Processing Record 23 of Set 7 | maltahohe
# Processing Record 24 of Set 7 | aklavik
# Processing Record 25 of Set 7 | port hedland
# Processing Record 26 of Set 7 | mitsamiouli
# Processing Record 27 of Set 7 | san cristobal
# Processing Record 28 of Set 7 | narsaq
# Processing Record 29 of Set 7 | penzance
# Processing Record 30 of Set 7 | henties bay
# Processing Record 31 of Set 7 | cessnock
# Processing Record 32 of Set 7 | baia-sprie
# City not found. Skipping...
# Processing Record 33 of Set 7 | ulaangom
# Processing Record 34 of Set 7 | vila
# Processing Record 35 of Set 7 | makakilo city
# Processing Record 36 of Set 7 | andoain
# Processing Record 37 of Set 7 | klaksvik
# Processing Record 38 of Set 7 | mount isa
# Processing Record 39 of Set 7 | slupca
# Processing Record 40 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 7 | jalu
# Processing Record 43 of Set 7 | mecca
# Processing Record 44 of Set 7 | west wendover
# Processing Record 45 of Set 7 | santa isabel do rio negro
# Processing Record 46 of Set 7 | yerbogachen
# Processing Record 47 of Set 7 | jiuquan
# Processing Record 48 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 49 of Set 7 | novoleushkovskaya
# Processing Record 0 of Set 8 | ilulissat
# Processing Record 1 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 2 of Set 8 | chokurdakh
# Processing Record 3 of Set 8 | acapulco
# Processing Record 4 of Set 8 | fort-shevchenko
# Processing Record 5 of Set 8 | ierapetra
# Processing Record 6 of Set 8 | dongsheng
# Processing Record 7 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 8 | labe
# Processing Record 9 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 8 | bar harbor
# Processing Record 11 of Set 8 | hundested
# Processing Record 12 of Set 8 | haines junction
# Processing Record 13 of Set 8 | linares
# Processing Record 14 of Set 8 | ye
# City not found. Skipping...
# Processing Record 15 of Set 8 | kangaatsiaq
# Processing Record 16 of Set 8 | ahipara
# Processing Record 17 of Set 8 | kushiro
# Processing Record 18 of Set 8 | sakyla
# Processing Record 19 of Set 8 | kendari
# Processing Record 20 of Set 8 | guerrero negro
# Processing Record 21 of Set 8 | saint-francois
# Processing Record 22 of Set 8 | brunico
# Processing Record 23 of Set 8 | roma
# Processing Record 24 of Set 8 | usvyaty
# Processing Record 25 of Set 8 | tomari
# Processing Record 26 of Set 8 | boca do acre
# Processing Record 27 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 8 | morehead
# Processing Record 29 of Set 8 | sakakah
# Processing Record 30 of Set 8 | geraldton
# Processing Record 31 of Set 8 | bilibino
# Processing Record 32 of Set 8 | lebu
# Processing Record 33 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 8 | porkhov
# Processing Record 35 of Set 8 | porto torres
# Processing Record 36 of Set 8 | roald
# Processing Record 37 of Set 8 | devarkonda
# Processing Record 38 of Set 8 | marsa matruh
# Processing Record 39 of Set 8 | goderich
# Processing Record 40 of Set 8 | burnie
# Processing Record 41 of Set 8 | kimbe
# Processing Record 42 of Set 8 | gobabis
# Processing Record 43 of Set 8 | vila velha
# Processing Record 44 of Set 8 | praia da vitoria
# Processing Record 45 of Set 8 | brajrajnagar
# City not found. Skipping...
# Processing Record 46 of Set 8 | kenora
# Processing Record 47 of Set 8 | san luis
# Processing Record 48 of Set 8 | plon
# Processing Record 49 of Set 8 | kapit
# Processing Record 0 of Set 9 | grenada
# Processing Record 1 of Set 9 | holme
# Processing Record 2 of Set 9 | azrow
# City not found. Skipping...
# Processing Record 3 of Set 9 | mamallapuram
# Processing Record 4 of Set 9 | mount gambier
# Processing Record 5 of Set 9 | tanjong tokong
# City not found. Skipping...
# Processing Record 6 of Set 9 | ukiah
# Processing Record 7 of Set 9 | balakovo
# Processing Record 8 of Set 9 | lar gerd
# City not found. Skipping...
# Processing Record 9 of Set 9 | chake chake
# Processing Record 10 of Set 9 | spirit river
# Processing Record 11 of Set 9 | harper
# Processing Record 12 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 9 | umba
# Processing Record 14 of Set 9 | noumea
# Processing Record 15 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 9 | ferme-neuve
# Processing Record 17 of Set 9 | tres arroyos
# Processing Record 18 of Set 9 | galveston
# Processing Record 19 of Set 9 | parabel
# Processing Record 20 of Set 9 | ahuimanu
# Processing Record 21 of Set 9 | high level
# Processing Record 22 of Set 9 | kaifeng
# Processing Record 23 of Set 9 | kibaya
# Processing Record 24 of Set 9 | sao jose da coroa grande
# Processing Record 25 of Set 9 | deputatskiy
# Processing Record 26 of Set 9 | marawi
# Processing Record 27 of Set 9 | nanchang
# Processing Record 28 of Set 9 | porbandar
# Processing Record 29 of Set 9 | vega de alatorre
# Processing Record 30 of Set 9 | morbach
# Processing Record 31 of Set 9 | bam
# Processing Record 32 of Set 9 | komsomolskiy
# Processing Record 33 of Set 9 | bosaso
# Processing Record 34 of Set 9 | longhua
# Processing Record 35 of Set 9 | harmanli
# Processing Record 36 of Set 9 | valdivia
# Processing Record 37 of Set 9 | bonavista
# Processing Record 38 of Set 9 | gwadar
# Processing Record 39 of Set 9 | kiama
# Processing Record 40 of Set 9 | kununurra
# Processing Record 41 of Set 9 | dondo
# Processing Record 42 of Set 9 | kutum
# Processing Record 43 of Set 9 | erzin
# Processing Record 44 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 45 of Set 9 | smithers
# Processing Record 46 of Set 9 | kindu
# Processing Record 47 of Set 9 | nantucket
# Processing Record 48 of Set 9 | muisne
# Processing Record 49 of Set 9 | dingle
# Processing Record 0 of Set 10 | salaga
# Processing Record 1 of Set 10 | ugoofaaru
# Processing Record 2 of Set 10 | inhambane
# Processing Record 3 of Set 10 | vostok
# Processing Record 4 of Set 10 | sobolevo
# Processing Record 5 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 10 | mana
# Processing Record 7 of Set 10 | bojnurd
# Processing Record 8 of Set 10 | sassandra
# Processing Record 9 of Set 10 | acarau
# Processing Record 10 of Set 10 | marsh harbour
# Processing Record 11 of Set 10 | grindavik
# Processing Record 12 of Set 10 | gaoual
# Processing Record 13 of Set 10 | changji
# Processing Record 14 of Set 10 | metu
# Processing Record 15 of Set 10 | salalah
# Processing Record 16 of Set 10 | kimberley
# Processing Record 17 of Set 10 | coihaique
# Processing Record 18 of Set 10 | sisimiut
# Processing Record 19 of Set 10 | nishihara
# Processing Record 20 of Set 10 | victoria point
# Processing Record 21 of Set 10 | goya
# Processing Record 22 of Set 10 | olinda
# Processing Record 23 of Set 10 | socorro
# Processing Record 24 of Set 10 | beloha
# Processing Record 25 of Set 10 | koslan
# Processing Record 26 of Set 10 | hamilton
# Processing Record 27 of Set 10 | maloy
# Processing Record 28 of Set 10 | buala
# Processing Record 29 of Set 10 | chernyshevskiy
# Processing Record 30 of Set 10 | amapa
# Processing Record 31 of Set 10 | kasempa
# Processing Record 32 of Set 10 | tondano
# Processing Record 33 of Set 10 | caravelas
# Processing Record 34 of Set 10 | sarkand
# Processing Record 35 of Set 10 | chebsara
# Processing Record 36 of Set 10 | buraydah
# Processing Record 37 of Set 10 | caborca
# Processing Record 38 of Set 10 | batagay-alyta
# Processing Record 39 of Set 10 | porosozero
# Processing Record 40 of Set 10 | tarumovka
# Processing Record 41 of Set 10 | bubaque
# Processing Record 42 of Set 10 | northam
# Processing Record 43 of Set 10 | sile
# Processing Record 44 of Set 10 | ponta delgada
# Processing Record 45 of Set 10 | lajeado
# Processing Record 46 of Set 10 | tabou
# Processing Record 47 of Set 10 | awjilah
# Processing Record 48 of Set 10 | karachi
# Processing Record 49 of Set 10 | takaka
# Processing Record 0 of Set 11 | camiri
# Processing Record 1 of Set 11 | mindelo
# Processing Record 2 of Set 11 | sayyan
# Processing Record 3 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 11 | kuching
# Processing Record 5 of Set 11 | presidencia roque saenz pena
# Processing Record 6 of Set 11 | bouca
# Processing Record 7 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 8 of Set 11 | princeton
# Processing Record 9 of Set 11 | dale
# Processing Record 10 of Set 11 | yatou
# Processing Record 11 of Set 11 | boende
# Processing Record 12 of Set 11 | sikonge
# Processing Record 13 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 15 of Set 11 | venado
# Processing Record 16 of Set 11 | avera
# Processing Record 17 of Set 11 | safaga
# Processing Record 18 of Set 11 | gawler
# Processing Record 19 of Set 11 | dong hoi
# Processing Record 20 of Set 11 | airai
# Processing Record 21 of Set 11 | ostersund
# Processing Record 22 of Set 11 | emerald
# Processing Record 23 of Set 11 | bolshaya dzhalga
# Processing Record 24 of Set 11 | south sioux city
# Processing Record 25 of Set 11 | xiuyan
# Processing Record 26 of Set 11 | tarabuco
# Processing Record 27 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 28 of Set 11 | sao sebastiao
# Processing Record 29 of Set 11 | bud
# Processing Record 30 of Set 11 | okha
# Processing Record 31 of Set 11 | svarstad
# Processing Record 32 of Set 11 | fairlie
# Processing Record 33 of Set 11 | hami
# Processing Record 34 of Set 11 | parkes
# Processing Record 35 of Set 11 | am timan
# Processing Record 36 of Set 11 | srednekolymsk
# Processing Record 37 of Set 11 | santiago
# Processing Record 38 of Set 11 | isangel
# Processing Record 39 of Set 11 | anadyr
# Processing Record 40 of Set 11 | pangnirtung
# Processing Record 41 of Set 11 | bac lieu
# Processing Record 42 of Set 11 | kaoma
# Processing Record 43 of Set 11 | makariv
# Processing Record 44 of Set 11 | cortez
# Processing Record 45 of Set 11 | bougouni
# Processing Record 46 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 11 | nhulunbuy
# Processing Record 49 of Set 11 | kuchera
# Processing Record 0 of Set 12 | beipiao
# Processing Record 1 of Set 12 | tsiroanomandidy
# Processing Record 2 of Set 12 | la palma
# Processing Record 3 of Set 12 | labytnangi
# Processing Record 4 of Set 12 | piopio
# Processing Record 5 of Set 12 | gudari
# Processing Record 6 of Set 12 | lianzhou
# Processing Record 7 of Set 12 | twentynine palms
# Processing Record 8 of Set 12 | rio gallegos
# Processing Record 9 of Set 12 | paita
# Processing Record 10 of Set 12 | marzuq
# Processing Record 11 of Set 12 | balakhta
# Processing Record 12 of Set 12 | mackay
# Processing Record 13 of Set 12 | batemans bay
# Processing Record 14 of Set 12 | guderup
# Processing Record 15 of Set 12 | westport
# Processing Record 16 of Set 12 | natal
# Processing Record 17 of Set 12 | nome
# Processing Record 18 of Set 12 | khorixas
# Processing Record 19 of Set 12 | cuenca
# Processing Record 20 of Set 12 | iqaluit
# Processing Record 21 of Set 12 | jaguaribe
# Processing Record 22 of Set 12 | dorado
# Processing Record 23 of Set 12 | kutoarjo
# Processing Record 24 of Set 12 | lucea
# Processing Record 25 of Set 12 | tondod
# Processing Record 26 of Set 12 | tianpeng
# Processing Record 27 of Set 12 | rocky mountain house
# Processing Record 28 of Set 12 | martinsicuro
# Processing Record 29 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 12 | yulin
# Processing Record 31 of Set 12 | shenjiamen
# Processing Record 32 of Set 12 | senador canedo
# Processing Record 33 of Set 12 | charyshskoye
# Processing Record 34 of Set 12 | kudahuvadhoo
# Processing Record 35 of Set 12 | tessalit
# Processing Record 36 of Set 12 | honningsvag
# Processing Record 37 of Set 12 | strezhevoy
# Processing Record 38 of Set 12 | huarmey
# Processing Record 39 of Set 12 | laurentides
# Processing Record 40 of Set 12 | college
# Processing Record 41 of Set 12 | pringsewu
# Processing Record 42 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 43 of Set 12 | port-cartier
# Processing Record 44 of Set 12 | taoudenni
# Processing Record 45 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 47 of Set 12 | necochea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          538
# Lat           538
# Lng           538
# Max Temp      538
# Humidity      538
# Cloudiness    538
# Wind Speed    538
# Country       538
# Date          538
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       gaur  26.7667   85.2667     19.62        50           0        2.16
# 1     kidodi  -7.6036   37.0044     21.74        97         100        1.46
# 2     kodiak  57.7900 -152.4072      2.73        93         100        1.54
# 3  esperance -33.8667  121.9000     30.22        39          73        7.05
# 4  cape town -33.9258   18.4232     21.62        85           0        6.17
#
#    Country        Date
# 0    19.62  1675654717
# 1    21.74  1675654718
# 2     2.73  1675654719
# 3    30.22  1675654719
# 4    21.62  1675654431

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             gaur  26.7667   85.2667     19.62        50           0
# 1           kidodi  -7.6036   37.0044     21.74        97         100
# 2           kodiak  57.7900 -152.4072      2.73        93         100
# 3        esperance -33.8667  121.9000     30.22        39          73
# 4        cape town -33.9258   18.4232     21.62        85           0
#
#          Wind Speed  Country        Date
# City_ID
# 0              2.16    19.62  1675654717
# 1              1.46    21.74  1675654718
# 2              1.54     2.73  1675654719
# 3              7.05    30.22  1675654719
# 4              6.17    21.62  1675654431

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature")
plt.xlabel("City Latitude")
plt.ylabel("Maximum City Temperate (Fahrenheit)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("City Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker='o')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (Miles per Hours)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def reglinefun(x_values, y_values, x_label, y_label, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept 
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,(10,10),fontsize=15,color='red')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    return plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                       dikson  73.5069   80.5464    -31.73       100
# 4                   georgetown   5.4112  100.3354     25.53        93
# 6                    vestmanna  62.1564   -7.1664      4.51        60
# 9                      aklavik  68.2191 -135.0107    -36.00        75
# 13       imeni poliny osipenko  52.4201  136.4853    -23.18        95
#
#          Cloudiness  Wind Speed  Country        Date
# City_ID
# 2               100        2.17   -31.73  1675730260
# 4                20        0.00    25.53  1675730108
# 6                75        8.23     4.51  1675730263
# 9                40        1.54   -36.00  1675730265
# 13              100        1.28   -23.18  1675730268

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  vaini -21.2000 -175.2000     24.09        94          75
# 1                 avarua -21.2078 -159.7750     29.03        79          40
# 3        bambous virieux -20.3428   57.7575     24.56        78          81
# 5         saint-philippe -21.3585   55.7679     25.77        85          67
# 7                 faanui -16.4833 -151.7500     27.37        76           9
#
#          Wind Speed  Country        Date
# City_ID
# 0              3.09    24.09  1675730259
# 1              4.63    29.03  1675730259
# 3              6.40    24.56  1675730261
# 5              4.95    25.77  1675730014
# 7              6.32    27.37  1675730263

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
reglinefun(northern_hemi_df["Max Temp"],northern_hemi_df["Lat"], 
                        "Maximum Temperature (F)", "Latitude", 
                        "Temperature vs. Latitude in the Northern Hemisphere")

# %%
# Linear regression on Southern Hemisphere
reglinefun(southern_hemi_df["Max Temp"],southern_hemi_df["Lat"], 
                        "Maximum Temperature (F)", "Latitude", 
                        "Temperature vs. Latitude in the Southern Hemisphere")

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere, there is strong negative correlation between latitude and temperature, meaning that as the latitude increases, the maximum temperature decreases. In the Southern Hemisphere, there is a weaker positive correlation between latitude and temperature, meaning that as the latitude decreases, the maximum temperature decreases at a much weaker correlation than the one shown in the Northern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
reglinefun(northern_hemi_df["Humidity"],northern_hemi_df["Lat"], 
                        "Humidity (%)", "Latitude", 
                        "Humidity vs. Latitude in the Northern Hemisphere")

# %%
# Southern Hemisphere
reglinefun(southern_hemi_df["Humidity"],southern_hemi_df["Lat"], 
                        "Humidity (%)", "Latitude", 
                        "Humidity vs. Latitude in the Southern Hemisphere")

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere, there is moderate positive correlation between humidity and temperature, meaning that as the latitude increases, the humidity increases. In the Southern Hemisphere, there is also a positive correlation between humidity and temperature. It is important to note that most of the data is skewed in the direction of higher humidity, meaning that the Southern Hempishere is generally more humid.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
reglinefun(northern_hemi_df["Cloudiness"],northern_hemi_df["Lat"], 
                        "Cloudiness", "Latitude", 
                        "Cloudiness vs. Latitude in the Northern Hemisphere")

# %%
# Southern Hemisphere
reglinefun(southern_hemi_df["Cloudiness"],southern_hemi_df["Lat"], 
                        "Cloudiness", "Latitude", 
                        "Cloudiness vs. Latitude in the Southern Hemisphere")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
